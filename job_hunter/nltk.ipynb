# %%
corpus=""" Hello! This is a sample Python script that demonstrates how to create a simple command-line application.
 The script includes basic functionality such as parsing command-line arguments and printing a greeting message."""

# %%
corpus
# Out:
# ' Hello! This is a sample Python script that demonstrates how to create a simple command-line application.\n The script includes basic functionality such as parsing command-line arguments and printing a greeting message.'

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/skipper/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sent_tokenize(corpus)
# Out:
# [' Hello!',
#  'This is a sample Python script that demonstrates how to create a simple command-line application.',
#  'The script includes basic functionality such as parsing command-line arguments and printing a greeting message.']
